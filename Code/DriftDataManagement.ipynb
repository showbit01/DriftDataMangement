# %%
import os
import random
import copy
import time
import numpy as np
import scipy.io

# %%
from google.colab import drive
drive.mount('/content/drive')
data1 = scipy.io.loadmat('/content/drive/My Drive/sea.mat')
data = data1.get('data')
n_feature = 3
# Out:
# Mounted at /content/drive

# %%
class nn(object):
    def __init__(self, layer):
        self.size = layer
        self.n = len(layer)
        self.hl = self.n - 2
        self.activation_func = "sigm"
        self.learningRate = 0.01
        self.momentum = 0.95
        self.outputConnect = 1
        self.output = "softmax"
        
        # initiate weights and weight momentum for hidden layer
        self.W = {}
        self.vW = {}
        self.dW = {}
        self.c = {}
        #self.W = self.vW  = self.dW= self.c = {} 
        for i in range(1, self.n-1):
            self.W[i] = np.random.normal(0, np.sqrt(2/(self.size[i-1]+1)), size=(self.size[i],self.size[i - 1]+1))
            self.vW[i] = np.zeros(self.W[i].shape)
            self.dW[i] = np.zeros(self.W[i].shape)
            self.c[i] =  np.random.normal(0, np.sqrt(2/(self.size[i-1]+1)), size=(self.size[i - 1],1))
        
        #initiate weights and weight momentum for output layer
        self.Ws = {}
        self.vWs = {}
        self.dWs =  {}
        self.beta = {}
        self.betaOld = {}
        self.p= {}  
        if self.outputConnect == 1:
            for i in range(1,(self.hl + 1)):
                self.Ws[i] = np.random.normal(0, np.sqrt(2/((self.W[i].shape[0])+1)), size=(self.size[len(self.size)-1],self.size[i]+1))
                self.vWs[i] = np.zeros(self.Ws[i].shape)
                self.dWs[i] = np.zeros(self.Ws[i].shape)         
                self.beta[i] = 1
                self.betaOld[i] = 1
                self.p[i]= 1 
        else:
            i = 1
            self.Ws[i] = np.random.normal(0, np.sqrt(2/((self.W[i-1].shape[0])+1)), size=(self.size[len(self.size)-1],self.size[len(self.size)-2]+1))
            self.vWs[i] = np.zeros(self.Ws[i].shape)
            self.dWs[i] = np.zeros(self.Ws[i].shape) 
            
        #initiate later used variable
        self.a = {}
        self.aas = {}
        self.e = {}
        self.L = {}
        self.classlabel = {}
        self.nop = {}
        self.nodes = {}

# %%
class Parameter(object):
    def __init__(self, nn,layer,K):
        self.nn = nn
        self.ev = {}
        self.size = layer
        self.prune_list       = 0;
        self.prune_list_index = [];
        self.ev[1] = {'layer': layer, 'kp':0, 'kl':0 ,'miu_x_old':0, 'var_x_old':0, 'kl':0,'K':K, 'cr':0,'node':{},
                     'BIAS2':{}, 'VAR':{}, 'miu_NS_old':0, 'var_NS_old':0, 'miu_NHS_old':0, 'var_NHS_old':0,
                     'miumin_NS':[], 'miumin_NHS':[], 'stdmin_NS':[], 'stdmin_NHS':[]}
        self.Loss = {}
        self.cr = {}
        self.wl = {}

# %%
class Performance(object):
    def __init__(self):
        self.update_time = 0
        self.ev = {}
        self.test_time = 0
        self.classification_time    = 0;
        self.layer = 0;
        self.ev[1] = {'f_measure': 0, 'g_mean':0, 'recall':0, 'precision':0}
        self.LayerWeight = 0
        self.meanode = []
        self.stdnode = []
        self.NumberOfParameters = 0

# %%
def sigmoid_array(x):                                        
    return 1 / (1 + np.exp(-x))

def relu_array(x):
    return abs(x) * (x > 0)

def softmax_array(x):
    list_re = []
    for arr in x:
        e_x = np.exp(arr - np.max(arr))
        result = e_x / e_x.sum()
        list_re.append(result)
    return np.array(list_re)  

def argmax_array(x):
    list_re = []
    for arr in x:
        result = [arr.argmax()]
        list_re.append(result)
    return np.array(list_re)  

def valuemax_array(x):
    list_re = []
    for arr in x:
        result = [arr.max()]
        list_re.append(result)
    return np.array(list_re)  

def update_beta(x):
    result = {}
    sum_val = sum(x.values())
#     if(all(value == 0 for value in x.values())):
#         return x
   
    for k, v in x.items():
        result[k] = v/sum_val        
    return result

def checkbeta(dict1):
    count = 0
    for i in dict1.values():
        if(i != 0):
            count += 1
    return count

# %%
def nettestparallel(nn, x, y, ev):
    nop = []
    #feedforward
    nn = netfeedforward(nn,x,y)
    (m1,m2) = y.shape
    compare0 = 0
    comparenot0 = 0
    #obtain true class
    act = argmax_array(y)
    for i in range(1,nn.hl+1):
        nn.classlabel[i] = {}
    if(len(nn.betaOld)>1):
        nn.sigma = np.zeros((m1,m2))
        for t in range(0,m1):
            for i in range(1,nn.hl+1):
                if(nn.beta[i] != 0):
                    #obtain predicted label, note : layer weight betaOld is fixed
                    nn.sigma[t] = nn.sigma[t] + (nn.aas[i][t] * nn.betaOld[i])               
                    nn.classlabel[i][t] = nn.aas[i][t].argmax()
                    compare = act[t][0] - nn.classlabel[i][t]
                    #train the weighted voting
                    if(compare != 0):
                        nn.beta[i] = max(nn.beta[i] * nn.p[i], 0)
                        nn.p[i] = max(nn.p[i] - 0.01 , 0)
                    elif(compare == 0):
                        nn.beta[i] = min(nn.beta[i] * (1+nn.p[i]), 1)
                        nn.p[i] = min(nn.p[i] + 0.01 , 1)

                #last element on data chunk        
                if(t==m1):
                    #calculate number of parameter
                    if(nn.beta[i] != 0):
                        (c,d) = nn.Ws[i].shape
                        vw = 1
                    else:
                        c = 0
                        d = 0
                        vw = 0
                    (a,b) = nn.W[i].shape
                    nop.append(a*b + c*d + vw)
                    
                    #calculate the number of node in each hidden layer
                    nn.nodes[i][nn.t] = ev[1]['K']
                    # print(nn.beta)
            nn.beta = update_beta(nn.beta);
            #print(nn.beta)
    elif(len(nn.betaOld)==1):
        nn.sigma = nn.aas[1]
        (c,d) = nn.Ws[1].shape
        vw = 1
        (a,b) = nn.W[1].shape
        nop = a*b + c*d + vw
        nn.nodes[1] = {nn.t : ev[1]['K']}
    
    nn.nop[nn.t] = np.sum(nop)

    nn.mnop = [np.array(list(nn.nop.values())).mean(),np.array(list(nn.nop.values())).std()]
    
    #update voting weight
    nn.betaOld = nn.beta.copy()
    nn.index = max(nn.beta, key=nn.beta.get)
    
    
    #calculate classification rate
    [raw_out, out] = [valuemax_array(nn.sigma), argmax_array(nn.sigma)]
    nn.bad = (np.where(out != act)[0]).reshape(-1,1)
    nn.cr = 1 - (nn.bad.shape[0]/m1)
    nn.residual_error = 1 - raw_out
    nn.out = out
    nn.act = act
    return [nn]
    #return nn,out,act,raw_out

# %%
def netfeedforward(nn,x,y):
    n = nn.n
    m = x.shape[0]
    ones = np.ones(shape= (m,1))
    x = np.append(ones, x, axis=1 ) #append columns of 1 in matrix for bias
    nn.a[1] = x
    #feedforward from input layer through all the hidden layer
    for i in range(2,n):
        if(nn.activation_func == 'sigm'):
            nn.a[i] = sigmoid_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        elif(nn.activation_func == 'relu'):
            nn.a[i] = relu_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        ones = np.ones(shape= (m,1))
        nn.a[i] = np.append(ones, nn.a[i], axis=1)
    
    #propagate to the output layer
    for i in range(1,nn.hl+1):
        if nn.beta[i] != 0:
            if(nn.output == 'sigm'):
                nn.aas[i] = sigmoid_array(np.matmul(nn.a[i+1], nn.Ws[i].T))
            elif(nn.output == 'linear'):
                nn.aas[i] = np.matmul(nn.a[i+1], nn.Ws[i].T)   
            elif(nn.output == 'softmax'):
                nn.aas[i] = softmax_array(np.matmul(nn.a[i+1],nn.Ws[i].T)) 
            
            
            #calculate error
            nn.e[i] = y - nn.aas[i]
               
            #calculate loss function
            if(nn.output == 'sigm' or nn.output == 'linear'):
                nn.L[i] = 0.5 * (np.sum(np.sum(nn.e[i]**2))) / m
            elif(nn.output == 'softmax'):
                nn.L[i] = -np.sum(np.sum(y * np.log(nn.aas[i]))) / m
        
            #print(nn.L) 
    return nn

# %%
#net configuration while training
def netconfigtrain(layer):
    net = nn(layer)
    net.layer = layer
    net.n = len(layer)
    net.activation_func = "sigm"
    net.learningRate = 0.01
    net.momentum = 0.95
    net.output = "softmax"
    return net

# %%
#calculate probit function
def probit(miu,std):
    p = (miu / (1+ np.pi * (std**2)/8) ** 0.5)
    return p

#calculate recursive mean and standard deviation
def meanstditer(miu_old, var_old,x,k):
    miu = miu_old + (x - miu_old) / k
    var = var_old + (x - miu_old) * (x-miu)
    std = np.sqrt(var/k)
  
    if(len(miu.shape) != 2):
        #print('len !=2')
        #print([np.array([miu]),np.array([std]),np.array([var])])
        return [np.array([miu]),np.array([std]),np.array([var])]
    else:
        return [miu,std,var]

# %%
def netffhl(nn, x):
    n = nn.n-1
    m = x.shape[0]
    ones = np.ones(shape= (m,1))
    x = np.append(ones, x, axis=1 ) #append columns of 1 in matrix for bias
    nn.a[1] = x
    #feedforward from input layer through all the hidden layer
    last = 0
    for i in range(2,n):
        last = i
        if(nn.activation_func == 'sigm'):
            nn.a[i] = sigmoid_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        elif(nn.activation_func == 'relu'):
            nn.a[i] = relu_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        ones = np.ones(shape= (m,1))
        nn.a[i] = np.append(ones, nn.a[i], axis=1 )
    y = nn.a[last]
    return y

# %%
def netffsingle(nn,x,y):
    x = np.array([x])
    y = np.array([y])
    n = nn.n
    m = x.shape[0]
    nn.a[1] = x
   
    #feedforward form input layer through all the hidden layer 
    for i in range(2,n):
        if(nn.activation_func == 'sigm'):
            nn.a[i] = sigmoid_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        elif(nn.activation_func == 'relu'):
            nn.a[i] = relu_array(np.matmul(nn.a[i-1],nn.W[i-1].T))
        ones = np.ones(shape= (m,1))
        nn.a[i] = np.append(ones, nn.a[i], axis=1 )
  
    #propagate to the output layer
    if(nn.output == 'sigm'):
        nn.a[n] = sigmoid_array(np.matmul(nn.a[n-1],nn.W[n-1].T))
    elif(nn.output == 'linear'):
        nn.a[n] = np.matmul(nn.a[n-1],nn.W[n-1].T)   
    elif(nn.output == 'softmax'):
        nn.a[n] = softmax_array(np.matmul(nn.a[n-1], nn.W[n-1].T)) 
            
    #calculate error
    nn.e[1] = y - nn.a[n]
    return nn

# %%
#calculate backpropagation
def netbackpropagation(nn):
    n = nn.n
    d = {}
    if(nn.output == 'sigm'):
        d[n] = - nn.e[1] * (nn.a[n] * (1 - nn.a[n]))      
    elif(nn.output == 'linear' or nn.output == 'softmax'):
        d[n] = -1 * nn.e[1]         
    for i in range(n-1, 1, -1):
        if(nn.activation_func == 'sigm'):
            d_act = nn.a[i] * (1 - nn.a[i])
        elif(nn.activation_func == 'tanh_opt'):
            d_act = 1.7159 * 2/3 * (1 - 1 / (1.7159**2) * (nn.a[i]**2))   
        elif(nn.activation_func == 'relu'):
            d_act = np.zeros((1,len(nn.a[i])))
            for i in range(len(d_act)):
                if(nn.a[i + 1]>0):
                    d_act[i] = 0             
        if(i+1 == n):
            d[i] = (np.matmul(d[i+1], nn.W[i]) * d_act)
        else:
            d[i] = (np.matmul(d[i+1][1:], nn.W[i]) * d_act)

    for i in range(1, n): 
        if(i+1 == n):
            nn.dW[i] = np.matmul(d[i+1].T, nn.a[i]) 
        else: 
            nn.dW[i] = np.matmul(d[i+1][:,1:].T, nn.a[i])   
    return nn

# %%
#update the weight
def netupdate(nn):
    for i in range(1, nn.n):
        dW = nn.dW[i]
        dW = nn.learningRate * dW       
        if(nn.momentum > 0):
            nn.vW[i] = nn.momentum * nn.vW[i] + dW
            dW = nn.vW[i]
        nn.W[i] = nn.W[i] - dW
    return nn

# %%
def nettrainsingle(parameter,x,y):
    bb = parameter.nn.W[parameter.nn.hl].shape[1]
    grow = 0
    prune=0
    
    #initialize performance matrix
    ly          = parameter.nn.hl
    kp          = parameter.ev[1]['kp']
    miu_x_old   = parameter.ev[1]['miu_x_old']
    var_x_old   = parameter.ev[1]['var_x_old']
    kl          = parameter.ev[ly]['kl']
    K           = parameter.ev[ly]['K']
    node        = parameter.ev[ly]['node']
    BIAS2       = parameter.ev[ly]['BIAS2']
    VAR         = parameter.ev[ly]['VAR']
    miu_NS_old  = parameter.ev[ly]['miu_NS_old']
    var_NS_old  = parameter.ev[ly]['var_NS_old']
    miu_NHS_old = parameter.ev[ly]['miu_NHS_old']
    var_NHS_old = parameter.ev[ly]['var_NHS_old']
    miumin_NS   = parameter.ev[ly]['miumin_NS']
    miumin_NHS  = parameter.ev[ly]['miumin_NHS']
    stdmin_NS   = parameter.ev[ly]['stdmin_NS']
    stdmin_NHS  = parameter.ev[ly]['stdmin_NHS']
    
    net = netconfigtrain([1,1,1])
    #substitute the weight to be trained to training model
    net.activation_func = parameter.nn.activation_func
    net.W[1]  = parameter.nn.W[ly]
    net.vW[1] = parameter.nn.vW[ly]
    net.dW[1] = parameter.nn.dW[ly]
    net.W[2]  = parameter.nn.Ws[ly]
    net.vW[2] = parameter.nn.vWs[ly]
    net.dW[2] = parameter.nn.dWs[ly]
   
    #load data in shuffled
    (N,I) = x.shape
    kk = np.random.permutation(N)
    ones = np.ones(shape= (N,1))
    x = x[kk]
    x = np.append(ones, x, axis=1 )
    y = y[kk]
    
    #xavier initialization
    n_in = parameter.ev[ly-1]['K']
    miuNS       = np.zeros((N,1))
    miuminNS       = np.zeros((N,1))
    miuNHS       = np.zeros((N,1))
    miuminNHS       = np.zeros((N,1))
    
    #main loop, train the model
    for k in range(1, N+1):
        kp = kp+1
        kl = kl+1
        #incremental calculation of x_tail mean and variance
        if(k <= parameter.nn.a[1].shape[0]):
            [miu_x, std_x, var_x] = meanstditer(miu_x_old,var_x_old,parameter.nn.a[1][k-1],kp)
            miu_x_old = miu_x
            var_x_old = var_x
            
            #expectation of z               
            py = probit(miu_x,std_x).T

            for ii in range(1, parameter.nn.hl+1):
                if(ii == parameter.nn.hl):
                    py = sigmoid_array(np.matmul(net.W[1],py))
                else:
                    py = sigmoid_array(np.matmul(parameter.nn.W[ii],py))
                py = np.append(np.array([[1]]),py, axis = 0)
                if(ii == 1):
                    Ey2 = py**2
            Ey = py
            Ez = np.matmul(net.W[2], Ey) 
            Ez = softmax_array(Ez.T).T
            
            if(parameter.nn.hl>1):
                py = Ey2
                for ii in range(2, parameter.nn.hl+1):
                    if(ii==parameter.nn.hl):
                        py = sigmoid_array(np.matmul(net.W[1],py))
                    else:
                        py = sigmoid_array(np.matmul(parameter.nn.W[ii],py))
                    py = np.append(np.array([[1]]),py, axis = 0)
                Ey2 = py
            Ez2 = np.matmul(net.W[2], Ey2) 
            Ez2 = softmax_array(Ez2.T).T
            
            #Network mean calculation  
            bias2 = (Ez - np.array([[1,0]]).T)**2
            ns = bias2
            NS = np.linalg.norm(ns, 'fro')
            
            #Incremental calculation of NS mean and variance
            [miu_NS,std_NS,var_NS] = meanstditer(miu_NS_old,var_NS_old,NS,kp)
            miu_NS_old = miu_NS
            var_NS_old = var_NS
            miustd_NS  = miu_NS + std_NS
            miuNS[k-1] = miu_NS

            if(kl <= 1 or grow ==1):
                miumin_NS = miu_NS
                stdmin_NS = std_NS
            else:
                if(miu_NS < miumin_NS):
                    miumin_NS = miu_NS
                    stdmin_NS = std_NS
                if(std_NS < stdmin_NS):
                    stdmin_NS = std_NS
            miuminNS = miumin_NS
            miustdmin_NS  = miumin_NS + (1.3*np.exp(-NS)+0.7)*stdmin_NS
            BIAS2[kl] = miu_NS
            
            #growing hidden unit
            if(miustd_NS >= miustdmin_NS and kl>1):
                grow = 1
                K=K+1
                print('The new node no {} is FORMED around sample {}'.format(K, k))
                node[kp] = K
                W_app = np.random.normal(0, np.sqrt(2/(n_in+1)), size=(1, bb))
                net.W[1] = np.append(net.W[1],W_app, axis = 0)          
                net.vW[1] = np.append(net.vW[1],np.zeros((1,bb)), axis = 0)
                net.dW[1] = np.append(net.dW[1],np.zeros((1,bb)), axis = 0)

                W2_app = np.random.normal(0, np.sqrt(2/(K+1)), size=(parameter.nn.size[-1], 1))
                net.W[2] = np.append(net.W[2],W2_app, axis = 1)
                net.vW[2] = np.append(net.vW[2],np.zeros((parameter.nn.size[-1], 1)), axis = 1)
                net.dW[2] = np.append(net.dW[2],np.zeros((parameter.nn.size[-1], 1)), axis = 1)   
            else:
                grow = 0
                node[kp] = K
                
            #Network variance calculation
            var = Ez2 - Ez**2
            NHS = np.linalg.norm(var, 'fro')
            
            # Incremental calculation of NHS mean and variance
            [miu_NHS,std_NHS,var_NHS] = meanstditer(miu_NHS_old,var_NHS_old,NHS,kp)
            miu_NHS_old = miu_NHS
            var_NHS_old = var_NHS
            miustd_NHS  = miu_NHS + std_NHS
            miuNHS[k-1] = miu_NHS

            if(kl <= I+1 or prune ==1):
                miumin_NHS = miu_NHS
                stdmin_NHS = std_NHS
            else:
                if(miu_NHS < miumin_NHS):
                    miumin_NHS = miu_NHS
                if(std_NHS < stdmin_NHS):
                    stdmin_NHS = std_NHS
            miustdmin_NHS  = miumin_NHS + (2.6*np.exp(-NHS)+1.4)*stdmin_NHS
            VAR[kl] = miu_NHS
            
            # Pruning hidden unit
            if(grow == 0 and K>1 and miustd_NHS >= miustdmin_NHS and kl>I+1):
                HS = Ey[1:]
                BB = np.argmin(HS)
                print('The node no {} is PRUNED around sample {}'.format(BB+1, k))
                prune = 1
                K = K-1
                node[kp] = K
                net.W[1] = np.delete(net.W[1],BB,axis =0)
                net.vW[1] = np.delete(net.vW[1],BB,axis =0)
                net.dW[1] = np.delete(net.dW[1],BB,axis =0)

                net.W[2] = np.delete(net.W[2],BB+1,axis =1)
                net.vW[2] = np.delete(net.vW[2],BB+1,axis =1)
                net.dW[2] = np.delete(net.dW[2],BB+1,axis =1)          
            else:
                prune = 0
                node[kp] = K
                
            #feedforward
            net = netffsingle(net, x[k-1],y[k-1])
        
        #feedforward #2, executed if there is a hidden node changing      
        net = netbackpropagation(net)
        net = netupdate(net)
        
     # subsitutte weight back to main model    
    parameter.nn.W[ly] = net.W[1]
    parameter.nn.Ws[ly] = net.W[2]
    
    #reset momentum and grandient
    parameter.nn.vW[ly] = net.vW[1] * 0
    parameter.nn.dW[ly] = net.dW[1] * 0
    parameter.nn.vWs[ly] = net.vW[2] * 0
    parameter.nn.dWs[ly] = net.dW[2] *0
    
    #substitute the recursive calculation
    parameter.ev[ly]['kl']          = kl
    parameter.ev[ly]['K']           = K
    parameter.ev[ly]['node']        = node
    parameter.ev[ly]['BIAS2']       = BIAS2
    parameter.ev[ly]['VAR']         = VAR
    parameter.ev[ly]['miu_NS_old']  = miu_NS_old
    parameter.ev[ly]['var_NS_old']  = var_NS_old
    parameter.ev[ly]['miu_NHS_old'] = miu_NHS_old
    parameter.ev[ly]['var_NHS_old'] = var_NHS_old
    parameter.ev[ly]['miumin_NS']   = miumin_NS
    parameter.ev[ly]['miumin_NHS']  = miumin_NHS
    parameter.ev[ly]['stdmin_NS']   = stdmin_NS
    parameter.ev[ly]['stdmin_NHS']  = stdmin_NHS                    
    return parameter

# %%
def nettrainparallel(parameter,y):
    bb = parameter.nn.W[parameter.nn.index].shape[1]
    grow = 0
    prune=0
    #initialize performance matrix
    ly          = parameter.nn.index
    kp          = parameter.ev[1]['kp']
    miu_x_old   = parameter.ev[1]['miu_x_old']
    var_x_old   = parameter.ev[1]['var_x_old']
    kl          = parameter.ev[ly]['kl']
    K           = parameter.ev[ly]['K']
    node        = parameter.ev[ly]['node']
    BIAS2       = parameter.ev[ly]['BIAS2']
    VAR         = parameter.ev[ly]['VAR']
    miu_NS_old  = parameter.ev[ly]['miu_NS_old']
    var_NS_old  = parameter.ev[ly]['var_NS_old']
    miu_NHS_old = parameter.ev[ly]['miu_NHS_old']
    var_NHS_old = parameter.ev[ly]['var_NHS_old']
    miumin_NS   = parameter.ev[ly]['miumin_NS']
    miumin_NHS  = parameter.ev[ly]['miumin_NHS']
    stdmin_NS   = parameter.ev[ly]['stdmin_NS']
    stdmin_NHS  = parameter.ev[ly]['stdmin_NHS']
    
    
    #initiate training model
    net = netconfigtrain([1,1,1])
    #substitute the weight to be trained to training model
    net.activation_func = parameter.nn.activation_func
    net.W[1]  = parameter.nn.W[ly]
    net.vW[1] = parameter.nn.vW[ly]
    net.dW[1] = parameter.nn.dW[ly]
    net.W[2]  = parameter.nn.Ws[ly]
    net.vW[2] = parameter.nn.vWs[ly]
    net.dW[2] = parameter.nn.dWs[ly]
    
    #load data in shuffled
    x = parameter.nn.a[ly]
    (N,I) = x.shape
    kk = np.random.permutation(N)
    x = x[kk]
    y = y[kk]
    
    #xavier initialization
    if(ly>1):
        n_in = parameter.ev[ly-1]['K']
    else:
        n_in = parameter.nn.size[0]

    miuNS       = np.zeros((N,1))
    miuminNS       = np.zeros((N,1))
    miuNHS       = np.zeros((N,1))
    miuminNHS       = np.zeros((N,1))

    
    #main loop, train the model
    for k in range(1, N+1):
        kp = kp+1
        kl = kl+1
        #incremental calculation of x_tail mean and variance
        [miu_x, std_x, var_x] = meanstditer(miu_x_old,var_x_old,parameter.nn.a[1][k-1],kp)
        miu_x_old = miu_x
        var_x_old = var_x

        #expectation of z
        py = probit(miu_x,std_x).T
      
        for ii in range(1, parameter.nn.index+1):
            if(ii == parameter.nn.index):
                py = sigmoid_array(np.matmul(net.W[1],py))
            else:
                py = sigmoid_array(np.matmul(parameter.nn.W[ii],py))
            py = np.append(np.array([[1]]),py, axis = 0)
            if(ii == 1):
                Ey2 = py**2

        Ey = py
        Ez = np.matmul(net.W[2], Ey) 
        Ez = softmax_array(Ez.T).T
        
        
        if(parameter.nn.hl>1):
            py = Ey2
            for ii in range(2, parameter.nn.index+1):
                if(ii==parameter.nn.index):
                    py = sigmoid_array(np.matmul(net.W[1],py))
                else:
                    py = sigmoid_array(np.matmul(parameter.nn.W[ii],py))
                py = np.append(np.array([[1]]),py, axis = 0)
            Ey2 = py
        Ez2 = np.matmul(net.W[2], Ey2) 
        Ez2 = softmax_array(Ez2.T).T
          
            
        #Network mean calculation  
        bias2 = (Ez - np.array([[1,0]]).T)**2
        ns = bias2
        NS = np.linalg.norm(ns, 'fro')

        #Incremental calculation of NS mean and variance
        [miu_NS,std_NS,var_NS] = meanstditer(miu_NS_old,var_NS_old,NS,kp)
        miu_NS_old = miu_NS
        var_NS_old = var_NS
        miustd_NS  = miu_NS + std_NS
        miuNS[k-1] = miu_NS
        
        if(kl <= 1 or grow ==1):
            miumin_NS = miu_NS
            stdmin_NS = std_NS
        else:
            if(miu_NS < miumin_NS):
                miumin_NS = miu_NS
                stdmin_NS = std_NS
            if(std_NS < stdmin_NS):
                stdmin_NS = std_NS
        miuminNS[k-1] = miumin_NS
        miustdmin_NS  = miumin_NS + (1.3*np.exp(-NS)+0.7)*stdmin_NS
        BIAS2[kl] = miu_NS
        
        #growing hidden unit
        if(miustd_NS >= miustdmin_NS and kl>1):
            grow = 1
            K=K+1
            print('The new node no {} is FORMED around sample {}'.format(K, k))
            node[kp] = K
            W_app = np.random.normal(0, np.sqrt(2/(n_in+1)), size=(1, bb))
            net.W[1] = np.append(net.W[1],W_app, axis = 0)          
            net.vW[1] = np.append(net.vW[1],np.zeros((1,bb)), axis = 0)
            net.dW[1] = np.append(net.dW[1],np.zeros((1,bb)), axis = 0)
            
            W2_app = np.random.normal(0, np.sqrt(2/(K+1)), size=(parameter.nn.size[-1], 1))
            net.W[2] = np.append(net.W[2],W2_app, axis = 1)
            net.vW[2] = np.append(net.vW[2],np.zeros((parameter.nn.size[-1], 1)), axis = 1)
            net.dW[2] = np.append(net.dW[2],np.zeros((parameter.nn.size[-1], 1)), axis = 1)
            
            if(ly<parameter.nn.hl):
                wNext = parameter.nn.W[ly+1].shape[0]
                parameter.nn.W[ly+1]  = np.append(parameter.nn.W[ly+1],np.random.normal(0, np.sqrt(2/(K+1)), size=(wNext, 1)), axis = 1)
                parameter.nn.vW[ly+1] = np.append(parameter.nn.vW[ly+1],np.zeros((wNext, 1)), axis = 1) 
                parameter.nn.dW[ly+1] = np.append(parameter.nn.dW[ly+1],np.zeros((wNext, 1)), axis = 1)         
        else:
            grow = 0
            node[kp] = K
        #Network variance calculation
#         ho = np.array([[0.7498],[0.2502]])
#         he = np.array([[0.7856],[0.2144]])
#         uy = ho-he**2
#         ey = np.linalg.norm(uy, 'fro')
       
        var = Ez2 - Ez**2
        NHS = np.linalg.norm(var, 'fro')
        
        # Incremental calculation of NHS mean and variance
        [miu_NHS,std_NHS,var_NHS] = meanstditer(miu_NHS_old,var_NHS_old,NHS,kp)
        miu_NHS_old = miu_NHS
        var_NHS_old = var_NHS
        miustd_NHS  = miu_NHS + std_NHS
        miuNHS[k-1] = miu_NHS
        
        if(kl <= I+1 or prune ==1):
            miumin_NHS = miu_NHS
            stdmin_NHS = std_NHS
        else:
            if(miu_NHS < miumin_NHS):
                miumin_NHS = miu_NHS
            if(std_NHS < stdmin_NHS):
                stdmin_NHS = std_NHS
        miuminNHS[k-1] = miumin_NHS
        miustdmin_NHS  = miumin_NHS + (2.6*np.exp(-NHS)+1.4)*stdmin_NHS
        VAR[kl] = miu_NHS
        
        # Pruning hidden unit
        if(grow == 0 and K>1 and miustd_NHS >= miustdmin_NHS and kl>I+1):
            HS = Ey[1:]
            BB = np.argmin(HS)
            print('The node no {} is PRUNED around sample {}'.format(BB+1, k))
            prune = 1
            K = K-1
            node[kp] = K
            net.W[1] = np.delete(net.W[1],BB,axis =0)
            net.vW[1] = np.delete(net.vW[1],BB,axis =0)
            net.dW[1] = np.delete(net.dW[1],BB,axis =0)
            
            net.W[2] = np.delete(net.W[2],BB+1,axis =1)
            net.vW[2] = np.delete(net.vW[2],BB+1,axis =1)
            net.dW[2] = np.delete(net.dW[2],BB+1,axis =1)
            if(ly<parameter.nn.hl):
                parameter.nn.W[ly+1]  = np.delete(parameter.nn.W[ly+1],BB+1,axis =1)
                parameter.nn.vW[ly+1] = np.delete(parameter.nn.vW[ly+1],BB+1,axis =1)
                parameter.nn.dW[ly+1] = np.delete(parameter.nn.dW[ly+1],BB+1,axis =1)            
        else:
            prune = 0
            node[kp] = K
        #feedforward
        net = netffsingle(net, x[k-1],y[k-1])
        
        #feedforward #2, executed if there is a hidden node changing      
        net = netbackpropagation(net)
        net = netupdate(net)
        
    # subsitutte weight back to main model    
    parameter.nn.W[ly] = net.W[1]
    parameter.nn.Ws[ly] = net.W[2]
    
    #reset momentum and grandient
    parameter.nn.vW[ly] = net.vW[1] * 0
    parameter.nn.dW[ly] = net.dW[1] * 0
    parameter.nn.vWs[ly] = net.vW[2] * 0
    parameter.nn.dWs[ly] = net.dW[2] *0
    
    #substitute the recursive calculation
    parameter.ev[1]['kp']           = kp
    parameter.ev[1]['miu_x_old']    = miu_x_old
    parameter.ev[1]['var_x_old']    = var_x_old
    parameter.ev[ly]['kl']          = kl
    parameter.ev[ly]['K']           = K
    parameter.ev[ly]['node']        = node
    parameter.ev[ly]['BIAS2']       = BIAS2
    parameter.ev[ly]['VAR']         = VAR
    parameter.ev[ly]['miu_NS_old']  = miu_NS_old
    parameter.ev[ly]['var_NS_old']  = var_NS_old
    parameter.ev[ly]['miu_NHS_old'] = miu_NHS_old
    parameter.ev[ly]['var_NHS_old'] = var_NHS_old
    parameter.ev[ly]['miumin_NS']   = miumin_NS
    parameter.ev[ly]['miumin_NHS']  = miumin_NHS
    parameter.ev[ly]['stdmin_NS']   = stdmin_NS
    parameter.ev[ly]['stdmin_NHS']  = stdmin_NHS
    #print(BIAS2)             
    return parameter

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Evaluation Method

# %%
#method for precission, recall, f1 score and gmean
def performance_summary(act_raw, out_raw, nclass):
    Act = to_one_hot(act_raw, nclass)
    Out = to_one_hot(out_raw, nclass)
    recall = compute_recall(Act, Out, nclass)
    precission = compute_precission(Act, Out, nclass)
    f_measure = compute_f_measure(Act, Out, nclass)
    g_mean = compute_g_mean(recall, nclass)
    return [g_mean, f_measure, precission, recall]

def compute_g_mean(recall, nclass):
    g_mean = (np.prod(recall))**(1/nclass) 
    return g_mean

def compute_f_measure(Act, Out, nclass):
    f_measure = np.zeros((1,nclass))    
    for c in range(nclass):
        f_measure[0][c] = (2 * (Act[:,c].T.dot(Out[:,c]))) / (np.sum(Out[:,c]) + np.sum(Act[:,c]))
    f_measure[np.isnan(f_measure)] = 1
    return f_measure

def compute_precission(Act, Out, nclass):
    precission = np.zeros((1,nclass))    
    for c in range(nclass):
        precission[0][c] = (Act[:,c].T.dot(Out[:,c])) / np.sum(Out[:,c])
    precission[np.isnan(precission)] = 1
    return precission
    
def compute_recall(Act, Out, nclass):
    recall = np.zeros((1,nclass))  
    for c in range(nclass):
        recall[0][c] = (Act[:,c].T.dot(Out[:,c])) / np.sum(Act[:,c])
    recall[np.isnan(recall)] = 1
    return recall

def to_one_hot(x, nclass):
    y = np.zeros((x.shape[0],nclass))
    for i in range(len(x)):
        y[i][x[i]] = 1
    return y

# %% [markdown]
# # Main Method

# %%
def test_ADL(data, n_feature):   
    (nData, n_column) = data.shape
    M = n_column - n_feature
    preq_data = data[:,0:n_feature]
    preq_label = data[:,n_feature:]  
    chunk_size = 500
    no_of_chunk = int(nData/chunk_size)
    
    drift = {}
    HL = {}
    buffer_x = []
    buffer_T = []
    tTest = []
    tTarget = []
    act = []
    out = []
    #initiate model 
    K = 1 #initial node
    network = nn([n_feature, K, M])
    
    #initiate node evolving iterative parameters
    layer = 1 #initial layer
    parameter = Parameter(network, layer,K)
    performance = Performance()
    
    # initiate drift detection parameter
    alpha_w = 0.0005;
    alpha_d = 0.0001;
    alpha   = 0.0001;
    
    #initiate layer merging iterative parameters
    covariance = np.zeros((1,1,2))
    covariance_old             = covariance
    threshold                  = 0.05
    
    ClassificationRate = {}
    for count in range(0,no_of_chunk):  
        # prepare data
        n = count + 1
        minibatch_data  = preq_data [(n-1)*chunk_size:n*chunk_size]
        minibatch_label = preq_label[(n-1)*chunk_size:n*chunk_size]
        
        # neural network testing      
        print('Chunk: {} of {}'.format(n, no_of_chunk))
        print('Discriminative Testing: running ...')
        parameter.nn.t = n
        [parameter.nn] = nettestparallel(parameter.nn,minibatch_data,minibatch_label,parameter.ev)
        
        #metrics calculation
        parameter.Loss[n] = parameter.nn.L[parameter.nn.index]
        if(n == 1):
            tTest = parameter.nn.sigma.copy()
            act = parameter.nn.act.copy()
            out = parameter.nn.out.copy()
            parameter.residual_error = np.append(out,parameter.nn.residual_error,axis=0)
        else:
            tTest = np.append(tTest,parameter.nn.sigma,axis=0)
            act = np.append(act,parameter.nn.act,axis=0)
            out = np.append(out,parameter.nn.out,axis=0)
            parameter.residual_error = np.append(out,parameter.nn.residual_error,axis=0)
        parameter.cr[n] = parameter.nn.cr;
        ClassificationRate[n] = np.array(list(parameter.cr.values())).mean()
        print('Classification rate {}'.format(ClassificationRate[n]))
        print('Discriminative Testing: ... finished')
        
        #statistical measure
        performance.ev[n] = {}
        [performance.ev[n]['f_measure'], performance.ev[n]['g_mean'] ,performance.ev[n]['recall'],performance.ev[n]['precision']] = performance_summary(parameter.nn.act, parameter.nn.out, M)
        #last chunk only for testing process
        if(n == no_of_chunk):
            print('=========Parallel Autonomous Deep Learning is finished=========')
            break

        #Drift detection: output space
        if(n>1):
            cuttingpoint = 0
            pp = minibatch_label.shape[0]
            F_cut = np.zeros((pp,1))
            F_cut[parameter.nn.bad] = 1
            Fupper = np.max(F_cut)
            Flower = np.min(F_cut)
            miu_F = np.mean(F_cut)
            
            for idx in range(pp):
                cut = idx + 1
                miu_G = np.mean(F_cut[0:cut])
                Gupper = np.max(F_cut[0:cut])
                Glower = np.min(F_cut[0:cut])
                epsilon_G = (Gupper - Glower) * np.sqrt(((pp)/(2*cut*(pp)) * np.log(1/alpha)))
                epsilon_F = (Fupper - Flower) * np.sqrt(((pp)/(2*cut*(pp)) * np.log(1/alpha)))
                if ((epsilon_G + miu_G) >= (miu_F + epsilon_F) and cut<pp):
                    cuttingpoint = cut
                    miu_H = np.mean(F_cut[(cuttingpoint):])
                    epsilon_D = (Fupper - Flower) * np.sqrt(((pp-cuttingpoint)/(2*cuttingpoint*(pp-cuttingpoint)) * np.log(1/alpha_d)))
                    epsilon_W = (Fupper - Flower) * np.sqrt(((pp-cuttingpoint)/(2*cuttingpoint*(pp-cuttingpoint)) * np.log(1/alpha_w)))
                    break
            if(cuttingpoint == 0):
                miu_H = miu_F
                epsilon_D = (Fupper - Flower) * np.sqrt(((pp)/(2*cut*(pp)) * np.log(1/alpha_d)))
                epsilon_W = (Fupper - Flower) * np.sqrt(((pp)/(2*cut*(pp)) * np.log(1/alpha_w)))
            
            #DRIFT STATUS
            if((np.abs(miu_G - miu_H)) > epsilon_D and cuttingpoint>1):
                st = 1
                print('Drift state: DRIFT')
                layer = layer+1
                parameter.nn.n = parameter.nn.n + 1
                parameter.nn.hl = layer
                print('The new Layer no {} is FORMED around chunk {}'.format(layer, n))
                
                #Initiate NN weight parameters
                ii = parameter.nn.W[layer-1].shape[0]
                parameter.nn.W[layer] = np.random.normal(0,np.sqrt(2/(ii+1)),size = (1, (ii+1)))    
                parameter.nn.vW[layer] = np.zeros((1,ii+1))
                parameter.nn.dW[layer] = np.zeros((1,ii+1))
                
                #Initiate new classifier weight
                parameter.nn.Ws[layer]  = np.random.normal(0,1,size = (M,2))    
                parameter.nn.vWs[layer] = np.zeros((M,2))
                parameter.nn.dWs[layer] = np.zeros((M,2))
                
                #Initiate new voting weight
                parameter.nn.beta[layer] = 1
                parameter.nn.betaOld[layer] = 1
                parameter.nn.p[layer] = 1
                
                # Initiate iterative parameters
                parameter.ev[layer] = {}
                parameter.ev[layer]['layer ']      = layer
                parameter.ev[layer]['kl']          = 0
                parameter.ev[layer]['K']           = 1
                parameter.ev[layer]['cr']           = 0
                parameter.ev[layer]['node']        = {}
                parameter.ev[layer]['miu_NS_old']  = 0
                parameter.ev[layer]['var_NS_old']  = 0
                parameter.ev[layer]['miu_NHS_old'] = 0
                parameter.ev[layer]['var_NHS_old'] = 0
                parameter.ev[layer]['miumin_NS']   = []
                parameter.ev[layer]['miumin_NHS']  = []
                parameter.ev[layer]['stdmin_NS']   = []
                parameter.ev[layer]['stdmin_NHS']  = []
                parameter.ev[layer]['BIAS2']       = {}
                parameter.ev[layer]['VAR']         = {} 
                
                #check buffer
                if(len(buffer_x) == 0):
                    h = parameter.nn.a[len(parameter.nn.a)][:,1:]
                    z = minibatch_label
                else:
                    buffer_x = netffhl(parameter.nn, buffer_x)
                    h = np.append(buffer_x[:,1:],parameter.nn.a[len(parameter.nn.a)][:,1:],axis=0)
                    if(len(buffer_T) == 0):
                        z = np.append(buffer_T,minibatch_label ,axis=0)
                    else:
                        z = minibatch_label
                        
                #Discriminative training for new layer
                print('Discriminative Training for new layer: running ...')
                parameter = nettrainsingle(parameter,h,z)
                print('Discriminative Training for new layer: ... finished')
                buffer_x = []
                buffer_T = []
            elif((np.abs(miu_G - miu_H)) >= epsilon_W and (np.abs(miu_G - miu_H)) < epsilon_D):
                st = 2
                print('Drift state: WARNING')
                buffer_x = minibatch_data
                buffer_T = minibatch_label
            else:
                st = 3
                print('Drift state: STABLE')
                buffer_x = []
                buffer_T = []
        else:
            st = 3
            print('Drift state: STABLE')
            buffer_x = []
            buffer_T = []
        drift[n] = st
        HL[n] = checkbeta(parameter.nn.beta)
        parameter.wl[n] = parameter.nn.index
        
        #Discriminative training for winning layer
        if(st != 1):
            print('Discriminative Training: running ...')
            parameter = nettrainparallel(parameter, minibatch_label)
            print('Discriminative Training: ... finished')
            
        #Clear current data chunk
        parameter.nn.a = {}
        print('=========Hidden layer number {} was updated========='.format(parameter.nn.index))
    return parameter,performance

# %%
if __name__ == "__main__":
    parameter, performance = test_ADL(data,n_feature)
# Out:
# Chunk: 1 of 200
# Discriminative Testing: running ...
# Classification rate 0.382
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 2 of 200
# Discriminative Testing: running ...
# Classification rate 0.5269999999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in double_scalars
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 3 of 200
# Discriminative Testing: running ...
# Classification rate 0.6106666666666666
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 4 of 200
# Discriminative Testing: running ...
# Classification rate 0.6809999999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 5 of 200
# Discriminative Testing: running ...
# Classification rate 0.7207999999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 6 of 200
# Discriminative Testing: running ...
# Classification rate 0.7373333333333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 7 of 200
# Discriminative Testing: running ...
# Classification rate 0.7594285714285715
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 8 of 200
# Discriminative Testing: running ...
# Classification rate 0.772
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 9 of 200
# Discriminative Testing: running ...
# Classification rate 0.7855555555555556
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 10 of 200
# Discriminative Testing: running ...
# Classification rate 0.796
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 11 of 200
# Discriminative Testing: running ...
# Classification rate 0.8014545454545455
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 12 of 200
# Discriminative Testing: running ...
# Classification rate 0.8031666666666668
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 13 of 200
# Discriminative Testing: running ...
# Classification rate 0.8058461538461539
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 14 of 200
# Discriminative Testing: running ...
# Classification rate 0.8098571428571429
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 15 of 200
# Discriminative Testing: running ...
# Classification rate 0.8082666666666667
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 16 of 200
# Discriminative Testing: running ...
# Classification rate 0.811875
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 17 of 200
# Discriminative Testing: running ...
# Classification rate 0.8148235294117647
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 18 of 200
# Discriminative Testing: running ...
# Classification rate 0.8192222222222223
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 19 of 200
# Discriminative Testing: running ...
# Classification rate 0.8234736842105264
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 20 of 200
# Discriminative Testing: running ...
# Classification rate 0.8251000000000002
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 21 of 200
# Discriminative Testing: running ...
# Classification rate 0.8280000000000001
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 22 of 200
# Discriminative Testing: running ...
# Classification rate 0.8285454545454546
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 23 of 200
# Discriminative Testing: running ...
# Classification rate 0.8295652173913044
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 24 of 200
# Discriminative Testing: running ...
# Classification rate 0.8313333333333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 25 of 200
# Discriminative Testing: running ...
# Classification rate 0.8321599999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 26 of 200
# Discriminative Testing: running ...
# Classification rate 0.8314615384615384
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 27 of 200
# Discriminative Testing: running ...
# Classification rate 0.8340740740740741
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 28 of 200
# Discriminative Testing: running ...
# Classification rate 0.8365
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 29 of 200
# Discriminative Testing: running ...
# Classification rate 0.838
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 30 of 200
# Discriminative Testing: running ...
# Classification rate 0.8402666666666666
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 31 of 200
# Discriminative Testing: running ...
# Classification rate 0.8419354838709677
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 32 of 200
# Discriminative Testing: running ...
# Classification rate 0.8434375
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 33 of 200
# Discriminative Testing: running ...
# Classification rate 0.8447878787878788
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 34 of 200
# Discriminative Testing: running ...
# Classification rate 0.8460588235294119
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 35 of 200
# Discriminative Testing: running ...
# Classification rate 0.8470857142857143
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 36 of 200
# Discriminative Testing: running ...
# Classification rate 0.8484444444444446
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 37 of 200
# Discriminative Testing: running ...
# Classification rate 0.8493513513513515
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 38 of 200
# Discriminative Testing: running ...
# Classification rate 0.8495789473684212
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 39 of 200
# Discriminative Testing: running ...
# Classification rate 0.8511794871794873
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 40 of 200
# Discriminative Testing: running ...
# Classification rate 0.8519
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 41 of 200
# Discriminative Testing: running ...
# Classification rate 0.8522439024390244
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 42 of 200
# Discriminative Testing: running ...
# Classification rate 0.853
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 43 of 200
# Discriminative Testing: running ...
# Classification rate 0.8520000000000001
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 44 of 200
# Discriminative Testing: running ...
# Classification rate 0.8523636363636364
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 45 of 200
# Discriminative Testing: running ...
# Classification rate 0.8523111111111112
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 46 of 200
# Discriminative Testing: running ...
# Classification rate 0.8536521739130436
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 47 of 200
# Discriminative Testing: running ...
# Classification rate 0.8540000000000001
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 48 of 200
# Discriminative Testing: running ...
# Classification rate 0.8547083333333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 49 of 200
# Discriminative Testing: running ...
# Classification rate 0.8544081632653061
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 50 of 200
# Discriminative Testing: running ...
# Classification rate 0.85508
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 51 of 200
# Discriminative Testing: running ...
# Classification rate 0.8538431372549019
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 52 of 200
# Discriminative Testing: running ...
# Classification rate 0.8543846153846153
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 53 of 200
# Discriminative Testing: running ...
# Classification rate 0.855132075471698
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 54 of 200
# Discriminative Testing: running ...
# Classification rate 0.8557037037037036
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 55 of 200
# Discriminative Testing: running ...
# Classification rate 0.8562181818181818
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 56 of 200
# Discriminative Testing: running ...
# Classification rate 0.8568571428571428
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 57 of 200
# Discriminative Testing: running ...
# Classification rate 0.8574736842105263
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 58 of 200
# Discriminative Testing: running ...
# Classification rate 0.8579655172413794
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 59 of 200
# Discriminative Testing: running ...
# Classification rate 0.8588474576271186
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 60 of 200
# Discriminative Testing: running ...
# Classification rate 0.8596999999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 61 of 200
# Discriminative Testing: running ...
# Classification rate 0.860295081967213
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 62 of 200
# Discriminative Testing: running ...
# Classification rate 0.8600967741935482
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 63 of 200
# Discriminative Testing: running ...
# Classification rate 0.8606031746031746
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 64 of 200
# Discriminative Testing: running ...
# Classification rate 0.8609375
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 65 of 200
# Discriminative Testing: running ...
# Classification rate 0.8614153846153847
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 66 of 200
# Discriminative Testing: running ...
# Classification rate 0.861939393939394
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 67 of 200
# Discriminative Testing: running ...
# Classification rate 0.8627164179104478
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 68 of 200
# Discriminative Testing: running ...
# Classification rate 0.8630000000000001
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 69 of 200
# Discriminative Testing: running ...
# Classification rate 0.8632463768115943
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 70 of 200
# Discriminative Testing: running ...
# Classification rate 0.8638285714285716
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 71 of 200
# Discriminative Testing: running ...
# Classification rate 0.8635774647887325
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 72 of 200
# Discriminative Testing: running ...
# Classification rate 0.8641944444444445
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 73 of 200
# Discriminative Testing: running ...
# Classification rate 0.8648219178082192
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 74 of 200
# Discriminative Testing: running ...
# Classification rate 0.865054054054054
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 75 of 200
# Discriminative Testing: running ...
# Classification rate 0.8655466666666666
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 76 of 200
# Discriminative Testing: running ...
# Classification rate 0.8634736842105263
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 77 of 200
# Discriminative Testing: running ...
# Classification rate 0.8639480519480519
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 78 of 200
# Discriminative Testing: running ...
# Classification rate 0.8642051282051282
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 79 of 200
# Discriminative Testing: running ...
# Classification rate 0.8645569620253164
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 80 of 200
# Discriminative Testing: running ...
# Classification rate 0.8646749999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 81 of 200
# Discriminative Testing: running ...
# Classification rate 0.8646913580246912
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 82 of 200
# Discriminative Testing: running ...
# Classification rate 0.8650487804878049
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# The new node no 2 is FORMED around sample 148
# The node no 1 is PRUNED around sample 149
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 83 of 200
# Discriminative Testing: running ...
# Classification rate 0.8646024096385542
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 84 of 200
# Discriminative Testing: running ...
# Classification rate 0.8647142857142857
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 85 of 200
# Discriminative Testing: running ...
# Classification rate 0.865035294117647
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# The new node no 2 is FORMED around sample 425
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 86 of 200
# Discriminative Testing: running ...
# Classification rate 0.8648837209302325
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 87 of 200
# Discriminative Testing: running ...
# Classification rate 0.8644367816091952
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 88 of 200
# Discriminative Testing: running ...
# Classification rate 0.8639772727272728
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 89 of 200
# Discriminative Testing: running ...
# Classification rate 0.8632134831460675
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# The new node no 3 is FORMED around sample 90
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 90 of 200
# Discriminative Testing: running ...
# Classification rate 0.8633777777777779
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 91 of 200
# Discriminative Testing: running ...
# Classification rate 0.8629890109890112
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 92 of 200
# Discriminative Testing: running ...
# Classification rate 0.8631956521739133
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 93 of 200
# Discriminative Testing: running ...
# Classification rate 0.8637419354838711
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 94 of 200
# Discriminative Testing: running ...
# Classification rate 0.8638297872340427
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 95 of 200
# Discriminative Testing: running ...
# Classification rate 0.8641052631578949
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 96 of 200
# Discriminative Testing: running ...
# Classification rate 0.8643124999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 97 of 200
# Discriminative Testing: running ...
# Classification rate 0.8637938144329895
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# The new node no 4 is FORMED around sample 240
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 98 of 200
# Discriminative Testing: running ...
# Classification rate 0.8639183673469386
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 99 of 200
# Discriminative Testing: running ...
# Classification rate 0.8639595959595958
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 100 of 200
# Discriminative Testing: running ...
# Classification rate 0.8638799999999998
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 101 of 200
# Discriminative Testing: running ...
# Classification rate 0.8636237623762373
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 102 of 200
# Discriminative Testing: running ...
# Classification rate 0.8649019607843135
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 103 of 200
# Discriminative Testing: running ...
# Classification rate 0.8661941747572813
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 104 of 200
# Discriminative Testing: running ...
# Classification rate 0.8673653846153846
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 105 of 200
# Discriminative Testing: running ...
# Classification rate 0.8683047619047619
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 106 of 200
# Discriminative Testing: running ...
# Classification rate 0.869377358490566
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 107 of 200
# Discriminative Testing: running ...
# Classification rate 0.870411214953271
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 108 of 200
# Discriminative Testing: running ...
# Classification rate 0.8714629629629629
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 109 of 200
# Discriminative Testing: running ...
# Classification rate 0.8724587155963303
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 110 of 200
# Discriminative Testing: running ...
# Classification rate 0.8734181818181818
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 111 of 200
# Discriminative Testing: running ...
# Classification rate 0.8743243243243243
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 112 of 200
# Discriminative Testing: running ...
# Classification rate 0.8753571428571428
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 113 of 200
# Discriminative Testing: running ...
# Classification rate 0.8760884955752212
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 114 of 200
# Discriminative Testing: running ...
# Classification rate 0.8768070175438596
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 115 of 200
# Discriminative Testing: running ...
# Classification rate 0.8775999999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 116 of 200
# Discriminative Testing: running ...
# Classification rate 0.8784137931034481
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 117 of 200
# Discriminative Testing: running ...
# Classification rate 0.8793504273504272
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 118 of 200
# Discriminative Testing: running ...
# Classification rate 0.8803728813559321
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 119 of 200
# Discriminative Testing: running ...
# Classification rate 0.8813445378151259
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 120 of 200
# Discriminative Testing: running ...
# Classification rate 0.8820833333333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 121 of 200
# Discriminative Testing: running ...
# Classification rate 0.8828925619834711
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 122 of 200
# Discriminative Testing: running ...
# Classification rate 0.8838360655737705
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 123 of 200
# Discriminative Testing: running ...
# Classification rate 0.8847642276422765
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 124 of 200
# Discriminative Testing: running ...
# Classification rate 0.8854838709677421
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 125 of 200
# Discriminative Testing: running ...
# Classification rate 0.8861760000000001
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 126 of 200
# Discriminative Testing: running ...
# Classification rate 0.8863968253968254
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 127 of 200
# Discriminative Testing: running ...
# Classification rate 0.8871811023622048
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 128 of 200
# Discriminative Testing: running ...
# Classification rate 0.887890625
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 129 of 200
# Discriminative Testing: running ...
# Classification rate 0.8884961240310078
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 130 of 200
# Discriminative Testing: running ...
# Classification rate 0.8891076923076924
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 131 of 200
# Discriminative Testing: running ...
# Classification rate 0.8897557251908397
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 132 of 200
# Discriminative Testing: running ...
# Classification rate 0.8902575757575757
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 133 of 200
# Discriminative Testing: running ...
# Classification rate 0.8908421052631579
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 134 of 200
# Discriminative Testing: running ...
# Classification rate 0.8913283582089552
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 135 of 200
# Discriminative Testing: running ...
# Classification rate 0.8917777777777777
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 136 of 200
# Discriminative Testing: running ...
# Classification rate 0.8924852941176472
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 137 of 200
# Discriminative Testing: running ...
# Classification rate 0.893051094890511
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 138 of 200
# Discriminative Testing: running ...
# Classification rate 0.8936811594202899
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 139 of 200
# Discriminative Testing: running ...
# Classification rate 0.8944028776978418
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 140 of 200
# Discriminative Testing: running ...
# Classification rate 0.8950714285714286
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 141 of 200
# Discriminative Testing: running ...
# Classification rate 0.8958014184397165
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 142 of 200
# Discriminative Testing: running ...
# Classification rate 0.8964225352112676
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 143 of 200
# Discriminative Testing: running ...
# Classification rate 0.8966013986013986
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 144 of 200
# Discriminative Testing: running ...
# Classification rate 0.8971944444444444
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 145 of 200
# Discriminative Testing: running ...
# Classification rate 0.8976827586206898
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 146 of 200
# Discriminative Testing: running ...
# Classification rate 0.8983561643835616
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 147 of 200
# Discriminative Testing: running ...
# Classification rate 0.8988979591836735
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 148 of 200
# Discriminative Testing: running ...
# Classification rate 0.8995135135135134
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 149 of 200
# Discriminative Testing: running ...
# Classification rate 0.9000536912751678
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 150 of 200
# Discriminative Testing: running ...
# Classification rate 0.9006666666666666
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 151 of 200
# Discriminative Testing: running ...
# Classification rate 0.9002649006622516
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 152 of 200
# Discriminative Testing: running ...
# Classification rate 0.9008157894736842
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 153 of 200
# Discriminative Testing: running ...
# Classification rate 0.9014248366013072
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 154 of 200
# Discriminative Testing: running ...
# Classification rate 0.9020259740259741
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 155 of 200
# Discriminative Testing: running ...
# Classification rate 0.9026064516129032
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 156 of 200
# Discriminative Testing: running ...
# Classification rate 0.9032307692307692
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 157 of 200
# Discriminative Testing: running ...
# Classification rate 0.9038471337579618
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 158 of 200
# Discriminative Testing: running ...
# Classification rate 0.9043291139240507
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 159 of 200
# Discriminative Testing: running ...
# Classification rate 0.9047798742138365
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 160 of 200
# Discriminative Testing: running ...
# Classification rate 0.9053374999999999
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 161 of 200
# Discriminative Testing: running ...
# Classification rate 0.9059006211180124
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 162 of 200
# Discriminative Testing: running ...
# Classification rate 0.9063333333333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 163 of 200
# Discriminative Testing: running ...
# Classification rate 0.9068834355828221
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 164 of 200
# Discriminative Testing: running ...
# Classification rate 0.9074024390243902
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 165 of 200
# Discriminative Testing: running ...
# Classification rate 0.9077939393939394
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 166 of 200
# Discriminative Testing: running ...
# Classification rate 0.908277108433735
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 167 of 200
# Discriminative Testing: running ...
# Classification rate 0.9087784431137724
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 168 of 200
# Discriminative Testing: running ...
# Classification rate 0.9092261904761905
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 169 of 200
# Discriminative Testing: running ...
# Classification rate 0.9096686390532543
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 170 of 200
# Discriminative Testing: running ...
# Classification rate 0.9101882352941175
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 171 of 200
# Discriminative Testing: running ...
# Classification rate 0.9106666666666666
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 172 of 200
# Discriminative Testing: running ...
# Classification rate 0.9110930232558138
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 173 of 200
# Discriminative Testing: running ...
# Classification rate 0.9115838150289016
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 174 of 200
# Discriminative Testing: running ...
# Classification rate 0.912045977011494
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 175 of 200
# Discriminative Testing: running ...
# Classification rate 0.9124799999999998
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 176 of 200
# Discriminative Testing: running ...
# Classification rate 0.9122386363636363
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 177 of 200
# Discriminative Testing: running ...
# Classification rate 0.9126327683615819
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 178 of 200
# Discriminative Testing: running ...
# Classification rate 0.9129662921348314
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 179 of 200
# Discriminative Testing: running ...
# Classification rate 0.91336312849162
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 180 of 200
# Discriminative Testing: running ...
# Classification rate 0.913711111111111
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 181 of 200
# Discriminative Testing: running ...
# Classification rate 0.9141325966850827
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 182 of 200
# Discriminative Testing: running ...
# Classification rate 0.9144835164835163
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 183 of 200
# Discriminative Testing: running ...
# Classification rate 0.9149180327868851
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 184 of 200
# Discriminative Testing: running ...
# Classification rate 0.9153804347826088
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 185 of 200
# Discriminative Testing: running ...
# Classification rate 0.9156756756756755
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 186 of 200
# Discriminative Testing: running ...
# Classification rate 0.9159569892473118
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 187 of 200
# Discriminative Testing: running ...
# Classification rate 0.9160427807486632
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 188 of 200
# Discriminative Testing: running ...
# Classification rate 0.9163936170212765
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# The new node no 5 is FORMED around sample 206
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 189 of 200
# Discriminative Testing: running ...
# Classification rate 0.9166455026455026
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 190 of 200
# Discriminative Testing: running ...
# Classification rate 0.916978947368421
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 191 of 200
# Discriminative Testing: running ...
# Classification rate 0.9173926701570679
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 192 of 200
# Discriminative Testing: running ...
# Classification rate 0.9176770833333333
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 193 of 200
# Discriminative Testing: running ...
# Classification rate 0.9180932642487047
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 194 of 200
# Discriminative Testing: running ...
# Classification rate 0.9184948453608247
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 195 of 200
# Discriminative Testing: running ...
# Classification rate 0.9186461538461537
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 196 of 200
# Discriminative Testing: running ...
# Classification rate 0.9190306122448979
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 197 of 200
# Discriminative Testing: running ...
# Classification rate 0.9194111675126901
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 198 of 200
# Discriminative Testing: running ...
# Classification rate 0.9197676767676767
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 199 of 200
# Discriminative Testing: running ...
# Classification rate 0.9200100502512563
# Discriminative Testing: ... finished
# Drift state: STABLE
# Discriminative Training: running ...
# Discriminative Training: ... finished
# =========Hidden layer number 1 was updated=========
# Chunk: 200 of 200
# Discriminative Testing: running ...
# Classification rate 0.9202699999999999
# Discriminative Testing: ... finished
# =========Parallel Autonomous Deep Learning is finished=========
